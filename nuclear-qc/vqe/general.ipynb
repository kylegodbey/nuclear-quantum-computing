# %% [markdown]
# # A General Case
#
# Author(s): Kyle Godbey
# Maintainer: Kyle Godbey
#
# To take this particular problem to its natural conclusion, we will be now devising a way to automatically generate our Hamiltonian and ansatz circuits based on what basis dimension we want to calculate.
#
# To do this in the most straightforward manner, I will first implement the Hamiltonian in second quantization before mapping it to a Pauli representation. To help out, I'll be importing some tools from qiskit as well as pennylane, proving that frameworks can indeed work together!

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from pennylane import numpy as np
import pennylane as qml
from qiskit_nature.operators.second_quantization import FermionicOp
from qiskit_nature.mappers.second_quantization import JordanWignerMapper, ParityMapper
import time
from functools import partial
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We'll also need some helper functions to parse Pauli strings and construct our pennylane Hamiltonian, so I'll just dump them here.

# %%
def pauli_token_to_operator(token):
    qubit_terms = []

    for term in range(len(token)):
        # Special case of identity
        if token[term] == "I":
            pass
        else:
            #pauli, qubit_idx = term, term
            if token[term] == "X":
                qubit_terms.append(qml.PauliX(int(term)))
            elif token[term] == "Y":
                qubit_terms.append(qml.PauliY(int(term)))
            elif token[term] == "Z":
                qubit_terms.append(qml.PauliZ(int(term)))
            else:
                print("Invalid input.")
    if(qubit_terms==[]):
            qubit_terms.append(qml.Identity(0))
    full_term = qubit_terms[0]
    for term in qubit_terms[1:]:
        full_term = full_term @ term

    return full_term


def parse_hamiltonian_input(input_data):
    # Get the input
    coeffs = []
    pauli_terms = []
    chunks = input_data.split("\n")
    # Go through line by line and build up the Hamiltonian
    for line in chunks:
        #line = line.strip()
        tokens = line.split(" ")
        # Parse coefficients
        sign, value = tokens[0][0], tokens[1]

        coeff = float(value)
        if sign == "-":
            coeff *= -1
        coeffs.append(coeff)

        # Parse Pauli component
        pauli = tokens[3]
        
        pauli_terms.append(pauli_token_to_operator(pauli))

    return qml.Hamiltonian(coeffs, pauli_terms)

# %% [markdown]
# Something else that will be very important is a function to compute the matrix elements $\langle n' | (\hat{T} + \hat{V}) | n \rangle$ needed for our Hamiltonian.

# %%
def kron(i,j):
    if(i==j):
        return 1
    else:
        return 0

def matrix_element(i,j):
    
    ele = 0.0
    
    ele = ((2.0*i + 1.5)*kron(i,j) - np.sqrt(i*(i+0.5))*kron(i,j+1) \
    - np.sqrt((i+1)*(i+1.5))*kron(i,j-1)) * 3.5
    
    ele += -5.68658111 * kron(i,0) * kron(i,j)
    
    
    return ele

# %% [markdown]
# Lastly, we'll make a function that returns a pennylane compatible Hamiltonian given a requested basis dimension, N.

# %%
def deuteron_ham(N,mapper=JordanWignerMapper):
    # Start out by zeroing what will be our fermionic operator
    op = 0
    for i in range(N):
        for j in range(N):
            # Construct the terms of the Hamiltonian in terms of creation/annihilation operators 
            op += matrix_element(i,j) * \
            FermionicOp([([("+", i),("-", j)], 1.0)])

    hamstr = "+ "+str(mapper().map(second_q_op=op))

    hamiltonian = parse_hamiltonian_input(hamstr)

    return hamiltonian

# %% [markdown]
# Let's take a look at our new Hamiltonian generator in the next code block. We'll start by setting the basis dimension to 3 so we can compare our two Hamiltonians: handcrafted and computer generated.

# %%
dim = 3

# Building our Hamiltonian for the N=3 case, as before

coeffs = [15.531709 ,-2.1433, -2.1433, 0.21829, -6.125, -9.625, -3.91, -3.91]
obs = [qml.Identity(0),qml.PauliX(0) @ qml.PauliX(1), qml.PauliY(0) @ qml.PauliY(1),qml.PauliZ(0),qml.PauliZ(1),qml.PauliZ(2),qml.PauliX(1) @ qml.PauliX(2),qml.PauliY(1) @ qml.PauliY(2)]

ham = qml.Hamiltonian(coeffs, obs)

# Let's print it out

print("Original Hamiltonian: \n",ham)

# Let's now use our new function!

H = deuteron_ham(dim)

print("Generated Hamiltonian: \n",H)
# Out:
# Original Hamiltonian:
#    (-9.625) [Z2]
# + (-6.125) [Z1]
# + (0.21829) [Z0]
# + (15.531709) [I0]
# + (-3.91) [X1 X2]
# + (-3.91) [Y1 Y2]
# + (-2.1433) [X0 X1]
# + (-2.1433) [Y0 Y1]
# Generated Hamiltonian:
#    (-9.625) [Z0]
# + (-6.125) [Z1]
# + (0.21829055499999983) [Z2]
# + (15.531709445) [I0]
# + (-3.913118960624632) [Y0 Y1]
# + (-3.913118960624632) [X0 X1]
# + (-2.1433035249352805) [Y1 Y2]
# + (-2.1433035249352805) [X1 X2]

# %% [markdown]
# We still need to define our device and circuit, so we'll let them be general as well.

# %%
dim = 6

# In this case we now need 3 qubits

dev = qml.device("default.qubit", wires=dim)

# Defining our ansatz circuit for the N=3 case

def circuit_3(params,wires):
    t0 = params[0]
    t1 = params[1]
    qml.PauliX(wires=0)
    qml.RY(t1, wires=1)
    qml.RY(t0, wires=2)
    qml.CNOT(wires=[2,0])
    qml.CNOT(wires=[0,1])
    qml.RY(-t1, wires=1)
    qml.CNOT(wires=[0,1])
    qml.CNOT(wires=[1,0])

# Define a general ansatz for arbitrary numbers of dimensions
# If the device you are running on doesn't support the arbitrary
# Rot gate, pennylane will attempt to decompose it

def circuit(params,wires=range(dim)):
    n_qubits = len(wires)
    n_rotations = len(params)
    if n_rotations > 1:
        n_layers = n_rotations // n_qubits
        n_extra_rots = n_rotations - n_layers * n_qubits

        # Alternating layers of unitary rotations on every qubit followed by a
        # ring cascade of CNOTs.
        for layer_idx in range(n_layers):
            layer_params = params[layer_idx * n_qubits : layer_idx * n_qubits + n_qubits, :]
            qml.broadcast(qml.Rot, wires, pattern="single", parameters=layer_params)
            qml.broadcast(qml.CNOT, wires, pattern="ring")

        # There may be "extra" parameter sets required for which it's not necessarily
        # to perform another full alternating cycle. Apply these to the qubits as needed.
        extra_params = params[-n_extra_rots:, :]
        extra_wires = wires[: n_qubits - 1 - n_extra_rots : -1]
        qml.broadcast(qml.Rot, extra_wires, pattern="single", parameters=extra_params)
    else:
        # For 1-qubit case, just a single rotation to the qubit
        qml.Rot(*params[0], wires=wires[0])

    return qml.expval(qml.SparseHamiltonian(H_sparse, wires=range(dim)))

def circuit_he(params,wires):
    n_qubits = len(wires)
    n_rotations = len(params)
    for i in range(n_qubits):
        qml.RY(params[i],wires=i)
    for i in range(n_qubits-1):
        qml.CNOT(wires=[i,i+1])
    for i in range(n_qubits):
        qml.RY(params[i+n_qubits], wires=i)

def arbsatz(params,wires):
    qml.ArbitraryStatePreparation(params, wires=wires)

particles = 1

ref_state = qml.qchem.hf_state(particles, dim)

singles, doubles = qml.qchem.excitations(particles, dim)

s_wires, d_wires = qml.qchem.excitations_to_wires(singles, doubles)
print(singles,doubles)
print(s_wires, d_wires)

ansatz = partial(qml.UCCSD, init_state=ref_state, s_wires=s_wires, d_wires=d_wires)
ansatz = partial(qml.templates.AllSinglesDoubles, hf_state=ref_state, singles=singles, doubles=doubles)
ansatz = partial(qml.ParticleConservingU2, init_state=ref_state)

layers = 5


# Defining Hamiltonian

H = deuteron_ham(dim)
H_sparse = qml.utils.sparse_hamiltonian(H)
#print(H_sparse)

cost_fn = qml.ExpvalCost(ansatz, H, dev)
# Out:
# [[0, 2], [0, 4]] []
# [[0, 1, 2], [0, 1, 2, 3, 4]] []

# %% [markdown]
# Amazing! That's an even better looking Hamiltonian!
#
# Now we'll set up what we'll need for the VQE procedure, this time doing a loop over how many parameters we'll need.

# %%
# Our parameter array, only one lonely element in this case :c

#init_params = np.array([2.5,4.5])
num_param_sets = (2 ** dim) - 1
init_params = np.random.uniform(low=-np.pi / 2, high=np.pi / 2, size=(num_param_sets, 3))
init_params = np.random.uniform(low=-np.pi / 2, high=np.pi / 2, size=qml.ArbitraryStatePreparation.shape(n_wires=dim))
init_params = np.random.uniform(low=-np.pi / 2, high=np.pi / 2, size=qml.ParticleConservingU2.shape(n_layers=layers, n_wires=dim))
#init_params = np.random.normal(0, 2*np.pi, len(singles) + len(doubles))
#init_params = np.random.normal(0, 2*np.pi, 2*dim)
# Convergence information and step size
#print(circuit(init_params))
max_iterations = 500
conv_tol = 1e-05
step_size = 0.05

# %% [markdown]
# Finally, the VQE block. We're still using the standard gradient descent optimizer since it worked so well before, but soon the time will come to shop around for better options.

# %%
opt = qml.QNGOptimizer(stepsize=step_size)

params = init_params

gd_param_history = [params]
gd_cost_history = []

accel = 0
prev_conv = -1.0

for n in range(max_iterations):
    fac = (1.0)
    opt = qml.GradientDescentOptimizer(stepsize=step_size)

    start = time.time()

    # Take a step in parameter space and record your energy
    params, prev_energy = opt.step_and_cost(cost_fn, params)

    # This keeps track of our energy for plotting at comparisons
    gd_param_history.append(params)
    gd_cost_history.append(prev_energy)

    # Here we see what the energy of our system is with the new parameters
    energy = cost_fn(params)

    # Calculate difference between new and old energies
    conv = np.abs(energy - prev_energy)

    if(energy - prev_energy > 0.0 and step_size > 0.001):
        print("Lowering!")
        accel = 0
        step_size = 0.5*step_size

    if(conv < prev_conv): accel += 1
    prev_conv = conv
    
    if(accel > 10 and step_size < 1.0):
        print("Accelerating!")
        step_size = 1.1*step_size
    end = time.time()
    if n % 1 == 0:
        print(
            "It = {:},  Energy = {:.8f} MeV,  Conv = {"
            ":.8f} MeV, Time Elapsed = {:.3f} s".format(n, energy, conv,end-start)
        )

    if conv <= conv_tol:
        break

print()
print("Final value of the energy = {:.8f} MeV".format(energy))
print("Number of iterations = ", n)
# Out:
# It = 0,  Energy = 20.62437840 MeV,  Conv = 5.53090087 MeV, Time Elapsed = 2.146 s
# It = 1,  Energy = 18.89463404 MeV,  Conv = 1.72974437 MeV, Time Elapsed = 1.864 s
# It = 2,  Energy = 18.46457504 MeV,  Conv = 0.43005900 MeV, Time Elapsed = 1.973 s
# It = 3,  Energy = 16.96569083 MeV,  Conv = 1.49888421 MeV, Time Elapsed = 1.999 s
# It = 4,  Energy = 14.08804312 MeV,  Conv = 2.87764771 MeV, Time Elapsed = 1.779 s
# It = 5,  Energy = 9.55988472 MeV,  Conv = 4.52815840 MeV, Time Elapsed = 1.773 s
# It = 6,  Energy = 4.87673798 MeV,  Conv = 4.68314674 MeV, Time Elapsed = 1.957 s
# It = 7,  Energy = 2.03237278 MeV,  Conv = 2.84436520 MeV, Time Elapsed = 1.985 s
# It = 8,  Energy = 0.80379090 MeV,  Conv = 1.22858189 MeV, Time Elapsed = 1.804 s
# It = 9,  Energy = 0.50063487 MeV,  Conv = 0.30315602 MeV, Time Elapsed = 1.971 s
# Lowering!
# It = 10,  Energy = 0.79264024 MeV,  Conv = 0.29200537 MeV, Time Elapsed = 1.797 s
# It = 11,  Energy = -1.03432419 MeV,  Conv = 1.82696442 MeV, Time Elapsed = 1.940 s
# It = 12,  Energy = -1.15049434 MeV,  Conv = 0.11617015 MeV, Time Elapsed = 2.247 s
# It = 13,  Energy = -1.22500892 MeV,  Conv = 0.07451459 MeV, Time Elapsed = 1.844 s
# It = 14,  Energy = -1.29169575 MeV,  Conv = 0.06668683 MeV, Time Elapsed = 1.979 s
# It = 15,  Energy = -1.35290118 MeV,  Conv = 0.06120543 MeV, Time Elapsed = 1.817 s
# It = 16,  Energy = -1.40966806 MeV,  Conv = 0.05676688 MeV, Time Elapsed = 1.980 s
# It = 17,  Energy = -1.46268403 MeV,  Conv = 0.05301597 MeV, Time Elapsed = 1.782 s
# It = 18,  Energy = -1.51241452 MeV,  Conv = 0.04973048 MeV, Time Elapsed = 1.778 s
# It = 19,  Energy = -1.55917912 MeV,  Conv = 0.04676460 MeV, Time Elapsed = 1.978 s
# It = 20,  Energy = -1.60320218 MeV,  Conv = 0.04402306 MeV, Time Elapsed = 1.968 s
# It = 21,  Energy = -1.64464688 MeV,  Conv = 0.04144470 MeV, Time Elapsed = 1.805 s
# It = 22,  Energy = -1.68363829 MeV,  Conv = 0.03899141 MeV, Time Elapsed = 1.965 s
# It = 23,  Energy = -1.72027893 MeV,  Conv = 0.03664064 MeV, Time Elapsed = 1.852 s
# It = 24,  Energy = -1.75465915 MeV,  Conv = 0.03438022 MeV, Time Elapsed = 1.820 s
# It = 25,  Energy = -1.78686390 MeV,  Conv = 0.03220475 MeV, Time Elapsed = 1.939 s
# It = 26,  Energy = -1.81697695 MeV,  Conv = 0.03011306 MeV, Time Elapsed = 1.999 s
# It = 27,  Energy = -1.84508334 MeV,  Conv = 0.02810638 MeV, Time Elapsed = 1.811 s
# It = 28,  Energy = -1.87127045 MeV,  Conv = 0.02618711 MeV, Time Elapsed = 1.948 s
# It = 29,  Energy = -1.89562836 MeV,  Conv = 0.02435790 MeV, Time Elapsed = 1.971 s
# It = 30,  Energy = -1.91824943 MeV,  Conv = 0.02262108 MeV, Time Elapsed = 1.779 s
# Accelerating!
# It = 31,  Energy = -1.93922773 MeV,  Conv = 0.02097829 MeV, Time Elapsed = 1.971 s
# Accelerating!
# It = 32,  Energy = -1.96055920 MeV,  Conv = 0.02133147 MeV, Time Elapsed = 1.752 s
# Accelerating!
# It = 33,  Energy = -1.98204719 MeV,  Conv = 0.02148799 MeV, Time Elapsed = 1.931 s
# Accelerating!
# It = 34,  Energy = -2.00346969 MeV,  Conv = 0.02142250 MeV, Time Elapsed = 1.993 s
# Accelerating!
# It = 35,  Energy = -2.02458588 MeV,  Conv = 0.02111619 MeV, Time Elapsed = 1.794 s
# Accelerating!
# It = 36,  Energy = -2.04514557 MeV,  Conv = 0.02055969 MeV, Time Elapsed = 1.778 s
# Accelerating!
# It = 37,  Energy = -2.06490110 MeV,  Conv = 0.01975553 MeV, Time Elapsed = 1.937 s
# Accelerating!
# It = 38,  Energy = -2.08362078 MeV,  Conv = 0.01871967 MeV, Time Elapsed = 1.944 s
# Accelerating!
# It = 39,  Energy = -2.10110211 MeV,  Conv = 0.01748133 MeV, Time Elapsed = 1.786 s
# Accelerating!
# It = 40,  Energy = -2.11718304 MeV,  Conv = 0.01608093 MeV, Time Elapsed = 1.955 s
# Accelerating!
# It = 41,  Energy = -2.13174927 MeV,  Conv = 0.01456623 MeV, Time Elapsed = 1.767 s
# Accelerating!
# It = 42,  Energy = -2.14473657 MeV,  Conv = 0.01298731 MeV, Time Elapsed = 1.913 s
# Accelerating!
# It = 43,  Energy = -2.15612833 MeV,  Conv = 0.01139176 MeV, Time Elapsed = 1.978 s
# Accelerating!
# It = 44,  Energy = -2.16594953 MeV,  Conv = 0.00982120 MeV, Time Elapsed = 1.933 s
# Accelerating!
# It = 45,  Energy = -2.17425957 MeV,  Conv = 0.00831004 MeV, Time Elapsed = 1.979 s
# Accelerating!
# It = 46,  Energy = -2.18114544 MeV,  Conv = 0.00688587 MeV, Time Elapsed = 1.789 s
# Accelerating!
# It = 47,  Energy = -2.18671155 MeV,  Conv = 0.00556611 MeV, Time Elapsed = 1.993 s
# Accelerating!
# It = 48,  Energy = -2.19091494 MeV,  Conv = 0.00420339 MeV, Time Elapsed = 2.021 s
# Lowering!
# It = 49,  Energy = -2.18775763 MeV,  Conv = 0.00315731 MeV, Time Elapsed = 1.790 s
# Lowering!
# It = 50,  Energy = -2.15542211 MeV,  Conv = 0.03233552 MeV, Time Elapsed = 1.773 s
# It = 51,  Energy = -2.17513397 MeV,  Conv = 0.01971185 MeV, Time Elapsed = 1.947 s
# It = 52,  Energy = -2.18558084 MeV,  Conv = 0.01044688 MeV, Time Elapsed = 1.970 s
# It = 53,  Energy = -2.19126209 MeV,  Conv = 0.00568124 MeV, Time Elapsed = 1.786 s
# It = 54,  Energy = -2.19439443 MeV,  Conv = 0.00313235 MeV, Time Elapsed = 1.957 s
# It = 55,  Energy = -2.19619072 MeV,  Conv = 0.00179628 MeV, Time Elapsed = 1.773 s
# It = 56,  Energy = -2.19726842 MeV,  Conv = 0.00107770 MeV, Time Elapsed = 1.945 s
# It = 57,  Energy = -2.19795964 MeV,  Conv = 0.00069121 MeV, Time Elapsed = 1.972 s
# It = 58,  Energy = -2.19843676 MeV,  Conv = 0.00047712 MeV, Time Elapsed = 1.790 s
# It = 59,  Energy = -2.19879212 MeV,  Conv = 0.00035537 MeV, Time Elapsed = 1.985 s
# It = 60,  Energy = -2.19907460 MeV,  Conv = 0.00028248 MeV, Time Elapsed = 1.764 s
# It = 61,  Energy = -2.19931072 MeV,  Conv = 0.00023612 MeV, Time Elapsed = 1.960 s
# It = 62,  Energy = -2.19951503 MeV,  Conv = 0.00020431 MeV, Time Elapsed = 1.951 s
# It = 63,  Energy = -2.19969582 MeV,  Conv = 0.00018079 MeV, Time Elapsed = 1.776 s
# It = 64,  Energy = -2.19985802 MeV,  Conv = 0.00016220 MeV, Time Elapsed = 1.766 s
# It = 65,  Energy = -2.20000474 MeV,  Conv = 0.00014672 MeV, Time Elapsed = 1.912 s
# It = 66,  Energy = -2.20013810 MeV,  Conv = 0.00013336 MeV, Time Elapsed = 1.964 s
# It = 67,  Energy = -2.20025967 MeV,  Conv = 0.00012157 MeV, Time Elapsed = 1.769 s
# It = 68,  Energy = -2.20037067 MeV,  Conv = 0.00011100 MeV, Time Elapsed = 1.968 s
# It = 69,  Energy = -2.20047212 MeV,  Conv = 0.00010145 MeV, Time Elapsed = 1.768 s
# It = 70,  Energy = -2.20056490 MeV,  Conv = 0.00009277 MeV, Time Elapsed = 1.930 s
# Accelerating!
# It = 71,  Energy = -2.20064976 MeV,  Conv = 0.00008487 MeV, Time Elapsed = 1.963 s
# Accelerating!
# It = 72,  Energy = -2.20073498 MeV,  Conv = 0.00008521 MeV, Time Elapsed = 1.769 s
# Accelerating!
# It = 73,  Energy = -2.20081977 MeV,  Conv = 0.00008479 MeV, Time Elapsed = 1.983 s
# Accelerating!
# It = 74,  Energy = -2.20090327 MeV,  Conv = 0.00008350 MeV, Time Elapsed = 1.767 s
# Accelerating!
# It = 75,  Energy = -2.20098454 MeV,  Conv = 0.00008126 MeV, Time Elapsed = 1.977 s
# Accelerating!
# It = 76,  Energy = -2.20106241 MeV,  Conv = 0.00007787 MeV, Time Elapsed = 2.009 s
# Accelerating!
# It = 77,  Energy = -2.20113481 MeV,  Conv = 0.00007240 MeV, Time Elapsed = 1.791 s
# Accelerating!
# It = 78,  Energy = -2.20119314 MeV,  Conv = 0.00005833 MeV, Time Elapsed = 1.783 s
# Lowering!
# It = 79,  Energy = -2.20117271 MeV,  Conv = 0.00002043 MeV, Time Elapsed = 1.918 s
# It = 80,  Energy = -2.20122734 MeV,  Conv = 0.00005463 MeV, Time Elapsed = 1.930 s
# It = 81,  Energy = -2.20127166 MeV,  Conv = 0.00004432 MeV, Time Elapsed = 1.763 s
# It = 82,  Energy = -2.20130812 MeV,  Conv = 0.00003646 MeV, Time Elapsed = 1.920 s
# It = 83,  Energy = -2.20133853 MeV,  Conv = 0.00003041 MeV, Time Elapsed = 1.766 s
# It = 84,  Energy = -2.20136422 MeV,  Conv = 0.00002569 MeV, Time Elapsed = 1.921 s
# It = 85,  Energy = -2.20138617 MeV,  Conv = 0.00002195 MeV, Time Elapsed = 1.984 s
# It = 86,  Energy = -2.20140513 MeV,  Conv = 0.00001896 MeV, Time Elapsed = 1.783 s
# It = 87,  Energy = -2.20142165 MeV,  Conv = 0.00001652 MeV, Time Elapsed = 1.963 s
# It = 88,  Energy = -2.20143617 MeV,  Conv = 0.00001451 MeV, Time Elapsed = 1.764 s
# It = 89,  Energy = -2.20144900 MeV,  Conv = 0.00001283 MeV, Time Elapsed = 1.937 s
# It = 90,  Energy = -2.20146041 MeV,  Conv = 0.00001141 MeV, Time Elapsed = 1.971 s
# It = 91,  Energy = -2.20147060 MeV,  Conv = 0.00001019 MeV, Time Elapsed = 1.760 s
# It = 92,  Energy = -2.20147973 MeV,  Conv = 0.00000913 MeV, Time Elapsed = 1.738 s
# It = 93,  Energy = -2.20148795 MeV,  Conv = 0.00000821 MeV, Time Elapsed = 1.921 s
# It = 94,  Energy = -2.20149535 MeV,  Conv = 0.00000740 MeV, Time Elapsed = 1.958 s
# It = 95,  Energy = -2.20150204 MeV,  Conv = 0.00000669 MeV, Time Elapsed = 1.781 s
# It = 96,  Energy = -2.20150808 MeV,  Conv = 0.00000605 MeV, Time Elapsed = 1.945 s
# It = 97,  Energy = -2.20151356 MeV,  Conv = 0.00000548 MeV, Time Elapsed = 1.753 s
# It = 98,  Energy = -2.20151852 MeV,  Conv = 0.00000496 MeV, Time Elapsed = 1.928 s
# It = 99,  Energy = -2.20152303 MeV,  Conv = 0.00000450 MeV, Time Elapsed = 1.997 s
# Accelerating!
# It = 100,  Energy = -2.20152712 MeV,  Conv = 0.00000409 MeV, Time Elapsed = 1.762 s
# Accelerating!
# It = 101,  Energy = -2.20153116 MeV,  Conv = 0.00000404 MeV, Time Elapsed = 1.930 s
# Accelerating!
# It = 102,  Energy = -2.20153512 MeV,  Conv = 0.00000396 MeV, Time Elapsed = 1.768 s
# Accelerating!
# It = 103,  Energy = -2.20153887 MeV,  Conv = 0.00000376 MeV, Time Elapsed = 1.948 s
# Accelerating!
# It = 104,  Energy = -2.20154210 MeV,  Conv = 0.00000323 MeV, Time Elapsed = 1.981 s
# Accelerating!
# It = 105,  Energy = -2.20154326 MeV,  Conv = 0.00000116 MeV, Time Elapsed = 1.896 s
# Lowering!
# It = 106,  Energy = -2.20153297 MeV,  Conv = 0.00001029 MeV, Time Elapsed = 1.884 s
# It = 107,  Energy = -2.20154456 MeV,  Conv = 0.00001159 MeV, Time Elapsed = 2.109 s
# It = 108,  Energy = -2.20154998 MeV,  Conv = 0.00000542 MeV, Time Elapsed = 2.047 s
# It = 109,  Energy = -2.20155286 MeV,  Conv = 0.00000288 MeV, Time Elapsed = 1.867 s
# It = 110,  Energy = -2.20155466 MeV,  Conv = 0.00000180 MeV, Time Elapsed = 1.966 s
# It = 111,  Energy = -2.20155597 MeV,  Conv = 0.00000131 MeV, Time Elapsed = 1.795 s
# It = 112,  Energy = -2.20155703 MeV,  Conv = 0.00000107 MeV, Time Elapsed = 1.906 s
# It = 113,  Energy = -2.20155796 MeV,  Conv = 0.00000093 MeV, Time Elapsed = 2.044 s
#
# Final value of the energy = -2.20155796 MeV
# Number of iterations =  113

# %% [markdown]
# As expected, we get closer to the true value with our expanded basis, though we're not all the way there. We still match our reference value very well, meaning we're on the right track for building out our robust nuclear VQE framework, so good job team!
#
# Let's plot the convergence next and see if going to 2-D hurt us any.

# %%
plt.style.use("seaborn")
plt.plot(gd_cost_history, "b", label="Gradient descent")
good = params
print(params)
plt.ylabel("Energy (MeV)")
plt.xlabel("Optimization steps")
plt.legend()
plt.show()
# Out:
# [[-1.43611503  0.44170403 -1.65472785]
#  [-1.03646289 -1.07805036  1.18567562]
#  [ 1.14205706 -0.93392006 -1.0370167 ]
#  [-0.86109287 -1.22334535 -0.40499659]
#  [ 0.23085791  0.22518157  0.05185782]
#  [ 1.24220446 -0.72379109 -0.97417589]
#  [ 0.97860879 -0.50512952  0.05970585]
#  [-0.71160103  0.75229758  0.54093147]
#  [ 0.25773309 -0.67825947 -1.80169203]
#  [-0.17631169  2.0435715   0.89952941]
#  [ 0.57819868 -0.24190579  0.07557548]
#  [-1.39318297  1.91023468 -1.41690015]
#  [-1.21149383  0.40647872 -0.05312088]
#  [-1.67764499  1.22746085  0.1669642 ]
#  [-0.47968628  1.25214951  0.08296357]
#  [-1.11962455 -1.32784896  1.31564872]
#  [-0.61902566  1.06558948 -0.16094066]
#  [ 0.02398786  0.04840668  0.37977987]
#  [-2.01902127  1.64924495  0.67575374]
#  [-0.16666318  0.57999779  1.66141197]
#  [ 1.2230436  -0.19542849 -1.7735324 ]
#  [ 0.94257024 -1.32462558 -0.95705655]
#  [ 0.91364992  0.34749849 -0.15685016]
#  [ 1.37838627  0.09783992 -1.45588818]
#  [ 0.70514738 -1.13542705 -0.41108211]
#  [-0.66195975 -1.06009678  0.63003702]
#  [ 0.04938787  0.39798286  1.06411209]
#  [-0.45566064 -0.12992944  1.07124777]
#  [-0.9087228   1.43820288 -0.86387032]
#  [ 0.83411681 -0.55837808  1.59202871]
#  [-0.56300331  1.28191076 -1.25999826]
#  [-0.7265027   0.77514275 -1.25233288]
#  [-0.7346878  -0.66657003 -0.94234767]
#  [-0.85598862 -0.5478078  -0.12671861]
#  [-1.2321566   0.64189108 -0.93741645]
#  [-0.78501856 -1.13211846 -1.09756446]
#  [-1.03221571  1.00128094  0.78933666]
#  [-0.8152301   0.93937857  0.12607574]
#  [-0.17835137  1.24349448 -0.00840111]
#  [-0.61160282  1.31114824  1.55759332]
#  [-1.62622312  1.56249976  0.84188218]
#  [ 0.12109203  1.01995023 -0.8073863 ]
#  [-0.4296737   0.99058094  1.3489908 ]
#  [ 0.20715834 -0.45429129 -1.06633254]
#  [-1.19452298  1.68798664  0.85178701]
#  [-1.26217369  1.24251417 -1.29965846]
#  [-0.592905   -0.59353358 -0.45437405]
#  [-1.59583961 -1.11491574 -0.38993757]
#  [-0.29415016 -0.34344616  1.31144863]
#  [ 0.84804725 -1.5826652   0.87333149]
#  [ 0.17849837  0.97672102 -0.59405051]
#  [ 1.06648518  1.16837897 -1.58365512]
#  [ 1.07048119 -1.09292152  0.24071434]
#  [ 0.0959548  -0.93963663  1.08841235]
#  [ 0.31105368  0.73775948  0.33802114]
#  [-1.18439551  0.33128196  0.78330676]
#  [ 0.94969518  0.15191051  0.65334557]
#  [ 0.36841171 -0.62540244 -0.50420988]
#  [ 0.12530301  0.53551912  0.27576127]
#  [-0.18375429  0.45509664 -0.60662364]
#  [-1.05324948  0.57855096 -1.67820771]
#  [-0.04563337 -0.18202297 -0.01542904]
#  [ 1.13126361  0.47629414 -0.48397113]]

# %% [markdown]
# Since we are now allowed to move in higher dimensions, making a general PES plotter gets a little tricky, but feel free to play around and see if you can think of clever ways to plot how your solution explores the space!
#
# This pretty much concludes our exploration of quantum computing for the deuteron from the point of view of Hamiltonian and state preparation, but there's plenty of other things that can be tried to improve performance! One approach would involce optimizing the ansatz instead of using a generic form, which could be a fun challenge. Another approach is to speed up the VQE algorithm itself, which is exactly what we'll be doing in the next section!
